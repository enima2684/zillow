# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read input
properties = pd.read_csv('data/properties_2016.csv')
samp_sub   = pd.read_csv('data/sample_submission.csv')
train      = pd.read_csv('data/train_2016_v2.csv')
# Out:
# C:\Programs\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print("shape of properties : {}".format(properties.shape))
print("======== Columns =========")
properties.dtypes
# Out:
# shape of properties : (2985217, 58)
# ======== Columns =========
# parcelid                          int64
# airconditioningtypeid           float64
# architecturalstyletypeid        float64
# basementsqft                    float64
# bathroomcnt                     float64
# bedroomcnt                      float64
# buildingclasstypeid             float64
# buildingqualitytypeid           float64
# calculatedbathnbr               float64
# decktypeid                      float64
# finishedfloor1squarefeet        float64
# calculatedfinishedsquarefeet    float64
# finishedsquarefeet12            float64
# finishedsquarefeet13            float64
# finishedsquarefeet15            float64
# finishedsquarefeet50            float64
# finishedsquarefeet6             float64
# fips                            float64
# fireplacecnt                    float64
# fullbathcnt                     float64
# garagecarcnt                    float64
# garagetotalsqft                 float64
# ...

# %%
print(properties.sample(10))
# Out:
#          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 1968124  11815507                    NaN                       NaN
# 587548   12453426                    NaN                       NaN
# 1128926  14223244                    NaN                       NaN
# 2411818  11182651                    1.0                       NaN
# 2096312  17204877                    NaN                       NaN
# 969916   11266422                    1.0                       NaN
# 1864617  11895346                    1.0                       NaN
# 1626910  12006748                    NaN                       NaN
# 2312565  12529292                    NaN                       NaN
# 2129202  11026953                    NaN                       NaN
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 1968124           NaN          2.0         3.0                  NaN
# 587548            NaN          3.0         4.0                  NaN
# ...

# %%
len(properties.parcelid.unique()) == len(properties)
# Out:
# True

# %%
print("Portion des données pour laquelle on a une donnée d'entrainement : {:.1f} %".format( len(train)/len(properties)*100))
# Out:
# Portion des données pour laquelle on a une donnée d'entrainement : 3.0 %

# %%
# Merge the training data with the features
train = pd.merge(left=train,
                 right=properties,
                 on='parcelid',
                 how='left')

# %%
len(train)
# Out:
# 90275

# %%
train.sample(10)
# Out:
#        parcelid  logerror transactiondate  airconditioningtypeid  \
# 37496  14286676    0.0742      2016-05-20                    NaN
# 15131  11945090   -0.0080      2016-03-09                    NaN
# 63135  14115088   -0.1555      2016-08-04                    NaN
# 48018  14175723   -0.0450      2016-06-22                    NaN
# 44130  11210989    0.0677      2016-06-10                    1.0
# 2247   11623323   -0.0010      2016-01-13                    1.0
# 63435  11629318    0.0109      2016-08-05                    NaN
# 41098  12509039    0.0853      2016-06-01                    NaN
# 55543  11166546   -0.0253      2016-07-14                    1.0
# 61636  10739718    0.0853      2016-07-29                    1.0
#
#        architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 37496                       NaN           NaN          2.5         3.0
# 15131                       NaN           NaN          6.0         6.0
# ...

# %%
sns.distplot(train.logerror)
train.logerror.describe()
# Out:
# C:\Programs\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# count    90275.000000
# mean         0.011457
# std          0.161079
# min         -4.605000
# 25%         -0.025300
# 50%          0.006000
# 75%          0.039200
# max          4.737000
# Name: logerror, dtype: float64
